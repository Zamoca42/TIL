# %% [markdown]
# <a href="https://colab.research.google.com/github/Zamoca42/TIL/blob/main/AI/HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 과제 3.
#
# 필기체 구분하는 인공신경망 Dense layer로 학습하고 보고서 작성
#
# 수업시간에 작성한 MNIST 데이터를 구분하는 Dense layer 신경망에서
#
# layer 숫자, units 숫자, activation, epoch 등 바꿔보면서 정확도 등을 평가

# %%
import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()

X_train = X_train.reshape(60000, 28*28)
X_test = X_test.reshape(-1, 28*28)

model = keras.models.Sequential([
    keras.layers.Dense(units=90, activation='relu', input_shape=[28*28]),
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# to_categorical -> categorical_crossentropy
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']) # one-hot encoding

hist = model.fit(X_train, Y_train, batch_size=1000, epochs=100, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.43696293234825134
# test accuracy: 0.9537000060081482

# %%
# layer 4개 추가

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data
(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()
# keras에서 제공하는 데이터

X_train = X_train.reshape(60000, 28*28) 
X_test = X_test.reshape(-1, 28*28)

model = keras.models.Sequential([
    keras.layers.Dense(units=90, activation='relu', input_shape=[28*28]),
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

hist = model.fit(X_train, Y_train, batch_size=1000, epochs=100, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.2612783908843994
# test accuracy: 0.9656000137329102

# %%
# units 30~150 변경

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()

X_train = X_train.reshape(60000, 28*28) 
X_test = X_test.reshape(-1, 28*28)

model = keras.models.Sequential([
    keras.layers.Dense(units=150, activation='relu', input_shape=[28*28]),
    keras.layers.Dense(units=150, activation='relu'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

hist = model.fit(X_train, Y_train, batch_size=1000, epochs=100, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.3504749536514282
# test accuracy: 0.9297999739646912

# %%
# activation 변경

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()


X_train = X_train.reshape(60000, 28*28) 
X_test = X_test.reshape(-1, 28*28)

model = keras.models.Sequential([
    keras.layers.Dense(units=90, activation='tanh', input_shape=[28*28]),
    keras.layers.Dense(units=30, activation='tanh'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

hist = model.fit(X_train, Y_train, batch_size=1000, epochs=100, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.15590299665927887
# test accuracy: 0.9519000053405762

# %%
# epoch 변경

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data
(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()
# keras에서 제공하는 데이터

X_train = X_train.reshape(60000, 28*28) # 원활한 학습을 위해 2D데이터를 1D데이터로 바꿔준다.
X_test = X_test.reshape(-1, 28*28) # 데이터 갯수를 정확히 모른다면 60000 자리에 -1넣으면 해결

model = keras.models.Sequential([
    keras.layers.Dense(units=90, activation='relu', input_shape=[28*28]),
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# to_categorical -> categorical_crossentropy
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']) # one-hot encoding

hist = model.fit(X_train, Y_train, batch_size=1000, epochs=150, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
# [0]에는 compile의 loss가 들어감
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.47408995032310486
# test accuracy: 0.9584000110626221

# %%
# batchsize 변경

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# https://www.tensorflow.org/api_docs/python/tf/keras/datasets/mnist/load_data
(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()
# keras에서 제공하는 데이터

X_train = X_train.reshape(60000, 28*28) # 원활한 학습을 위해 2D데이터를 1D데이터로 바꿔준다.
X_test = X_test.reshape(-1, 28*28) # 데이터 갯수를 정확히 모른다면 60000 자리에 -1넣으면 해결

model = keras.models.Sequential([
    keras.layers.Dense(units=90, activation='relu', input_shape=[28*28]),
    keras.layers.Dense(units=30, activation='relu'), 
    keras.layers.Dense(units=10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# to_categorical -> categorical_crossentropy
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']) # one-hot encoding

hist = model.fit(X_train, Y_train, batch_size=500, epochs=100, validation_split=0.2, shuffle=True, verbose = 0)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
# [0]에는 compile의 loss가 들어감
print("test accuracy:", score[1])

# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# test loss: 0.3129802346229553
# test accuracy: 0.963100016117096

# %%
# 최적화

import tensorflow
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# 데이터 가져오기
(X_train, Y_train),(X_test,Y_test) = keras.datasets.mnist.load_data()

# 데이터 가공하기
X_train, X_test = X_train/255.0, X_test/255.0

# 신경망 구성하기
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax'),
])

opt = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
# to_categorical -> categorical_crossentropy
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy']) # one-hot encoding

# 학습시키기
hist = model.fit(X_train, Y_train, batch_size = 500, epochs=35, validation_split=0.2)

# 평가
score = model.evaluate(X_test,Y_test, verbose=0)
print("test loss:", score[0])
print("test accuracy:", score[1])
# Out:
# Epoch 1/35
# 96/96 [==============================] - 1s 6ms/step - loss: 0.4777 - accuracy: 0.8710 - val_loss: 0.2129 - val_accuracy: 0.9392
# Epoch 2/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9477 - val_loss: 0.1461 - val_accuracy: 0.9592
# Epoch 3/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9638 - val_loss: 0.1237 - val_accuracy: 0.9622
# Epoch 4/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9738 - val_loss: 0.1116 - val_accuracy: 0.9665
# Epoch 5/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9805 - val_loss: 0.0925 - val_accuracy: 0.9707
# Epoch 6/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9845 - val_loss: 0.0917 - val_accuracy: 0.9716
# Epoch 7/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9887 - val_loss: 0.0821 - val_accuracy: 0.9749
# Epoch 8/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9916 - val_loss: 0.0859 - val_accuracy: 0.9752
# Epoch 9/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9935 - val_loss: 0.0819 - val_accuracy: 0.9755
# Epoch 10/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9954 - val_loss: 0.0832 - val_accuracy: 0.9758
# Epoch 11/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 0.9969 - val_loss: 0.0828 - val_accuracy: 0.9754
# Epoch 12/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9978 - val_loss: 0.0840 - val_accuracy: 0.9763
# Epoch 13/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.0811 - val_accuracy: 0.9768
# Epoch 14/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9993 - val_loss: 0.0816 - val_accuracy: 0.9769
# Epoch 15/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 0.9995 - val_loss: 0.0806 - val_accuracy: 0.9783
# Epoch 16/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.0826 - val_accuracy: 0.9785
# Epoch 17/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0837 - val_accuracy: 0.9778
# Epoch 18/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0846 - val_accuracy: 0.9774
# Epoch 19/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0831 - val_accuracy: 0.9784
# Epoch 20/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9782
# Epoch 21/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9787
# Epoch 22/35
# 96/96 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9792
# Epoch 23/35
# 96/96 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9786
# Epoch 24/35
# 96/96 [==============================] - 0s 4ms/step - loss: 9.4186e-04 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9788
# Epoch 25/35
# 96/96 [==============================] - 0s 4ms/step - loss: 8.3961e-04 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 0.9796
# Epoch 26/35
# 96/96 [==============================] - 0s 4ms/step - loss: 7.5026e-04 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 0.9793
# Epoch 27/35
# 96/96 [==============================] - 0s 4ms/step - loss: 6.7676e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9794
# Epoch 28/35
# 96/96 [==============================] - 0s 4ms/step - loss: 6.0769e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9793
# Epoch 29/35
# 96/96 [==============================] - 0s 4ms/step - loss: 5.4806e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9797
# Epoch 30/35
# 96/96 [==============================] - 0s 3ms/step - loss: 4.9926e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9790
# Epoch 31/35
# 96/96 [==============================] - 0s 4ms/step - loss: 4.5882e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9790
# Epoch 32/35
# 96/96 [==============================] - 0s 3ms/step - loss: 4.1622e-04 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9796
# Epoch 33/35
# 96/96 [==============================] - 0s 4ms/step - loss: 3.8111e-04 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9794
# Epoch 34/35
# 96/96 [==============================] - 0s 4ms/step - loss: 3.4734e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9794
# Epoch 35/35
# 96/96 [==============================] - 0s 4ms/step - loss: 3.2043e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9795
# test loss: 0.07965683937072754
# test accuracy: 0.9824000000953674

# %%
# prediction과 맞는지 비교

for i in range(10):
  n = int(np.random.rand()*10000)
  print("n:", n)
  print("predict: ", np.argmax(model.predict(X_test[n].reshape(1,28,28,1)),axis=1))
  print("True_value :", Y_test[n])

  plt.imshow(X_test[n].reshape(28,28), cmap='Greys', interpolation='nearest')
  plt.show()
# Out:
# n: 9131
# 1/1 [==============================] - 0s 51ms/step
# predict:  [2]
# True_value : 2
# n: 7830
# 1/1 [==============================] - 0s 15ms/step
# predict:  [0]
# True_value : 0
# n: 3265
# 1/1 [==============================] - 0s 15ms/step
# predict:  [0]
# True_value : 0
# n: 2554
# 1/1 [==============================] - 0s 15ms/step
# predict:  [5]
# True_value : 5
# n: 5206
# 1/1 [==============================] - 0s 14ms/step
# predict:  [5]
# True_value : 5
# n: 4133
# 1/1 [==============================] - 0s 13ms/step
# predict:  [2]
# True_value : 2
# n: 5119
# 1/1 [==============================] - 0s 15ms/step
# predict:  [2]
# True_value : 2
# n: 5592
# 1/1 [==============================] - 0s 16ms/step
# predict:  [0]
# True_value : 0
# n: 6996
# 1/1 [==============================] - 0s 15ms/step
# predict:  [9]
# True_value : 9
# n: 84
# 1/1 [==============================] - 0s 15ms/step
# predict:  [8]
# True_value : 8

# %%
# pyplot

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Modelloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
